# %% [markdown]
# [![](images/colab-badge.png)](https://colab.research.google.com/github/fzampirolli/si-md2/blob/main/si-md2/notebooks_alunos/cap06/cap06_aluno.ipynb)

# %% [markdown]
# # Aplicações Práticas e Estudos de Caso

# %% [markdown]
# For a demonstration of a line plot, see @fig-line-plot.

# %%
#| label: fig-line-plot
#| fig-cap: "A line plot "

import matplotlib.pyplot as plt
plt.plot([1,23,2,4])
plt.show()

# %% [markdown]
# Exemplo de figura @fig-2-1.
#
# ![Relação entre Dados, Informação e Conhecimento](images/fig1_1.png){#fig-2-1 .lightbox fig-alt="A drawing of an elephant." fig-align="left" width=20%}

# %% [markdown]
# Exemplo de tabela-imagem @tbl-2-1.
#
# ![Relação entre Dados, Informação e Conhecimento](images/fig1_1.png){#tbl-2-1}

# %% [markdown]
# A tabela @tbl-1-X.
#
# | x | y |
# |---|---|
# | 1 | 2 |
#
# : Legenda da tabela {#tbl-1-X}

# %% [markdown]
# A equação @eq-1-1.
#
# $$
# x^3
# $$ {#eq-1-1}

# %% [markdown]
# ## Referências do Capítulo
#
# Tem que citar neste capítulo: @han2008, @tan2009, @witten2005, @goldschmidt2005
#
# \printbibliography[heading=none]
