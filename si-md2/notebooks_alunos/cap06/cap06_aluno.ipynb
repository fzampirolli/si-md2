# %% [markdown]
# [![](images/colab-badge.png)](https://colab.research.google.com/github/fzampirolli/si-md2/blob/main/si-md2/notebooks_alunos/cap06/cap06_aluno.ipynb)

# %% [markdown]
# # Aplicações Práticas e Estudos de Caso

# %% [markdown]
# For a demonstration of a line plot, see [Figura 1](#fig-line-plot).

# %%
import matplotlib.pyplot as plt
plt.plot([1,23,2,4])
plt.show()
# Out:
# **Figura 1:** A line plot

# %% [markdown]
# Exemplo de figura [Figura 2.2](#fig-2-1).
#
# <figure id="fig-2-1">
#   <img src="images/fig1_1.png" alt="Relação entre Dados, Informação e Conhecimento" style="max-width:100%" />
#   <figcaption><strong>Figura 2.2:</strong> Relação entre Dados, Informação e Conhecimento</figcaption>
# </figure>

# %% [markdown]
# Exemplo de tabela-imagem [Tabela 2.1](#tbl-2-1).
#
# <figure id="tbl-2-1">
#   <figcaption><strong>Tabela 2.1:</strong> Relação entre Dados, Informação e Conhecimento</figcaption>
#   <img src="images/fig1_1.png" alt="Relação entre Dados, Informação e Conhecimento" style="max-width:100%" />
# </figure>

# %% [markdown]
# A tabela [Tabela 1.2](#tbl-1-X).
#
# <a id="tbl-1-X"></a>
#
# **Tabela 1.2:** Legenda da tabela
#
# | x | y |
# |---|---|
# | 1 | 2 |

# %% [markdown]
# A equação [Equação 1.1](#eq-1-1).
#
# <a id="eq-1-1"></a>
# $$
# x^3 \tag{1.1}
# $$

# %% [markdown]
# ## Referências do Capítulo
#
#
# Tem que citar neste capítulo: Han e Kamber (2008), Tan et al. (2009), Witten e Frank (2005), Goldschmidt e Passos (2005)
#
# GOLDSCHMIDT, R.; PASSOS, E. **Data Mining: Um Guia Prático**. Elsevier, 2005.
#
# HAN, J.; KAMBER, M. **Data Mining: Concepts and Techniques**. Morgan Kaufmann Publishers, 2008.
#
# TAN, P.N.; STEINBACH, M.; KUMAR, V. **Introdução ao Data Mining Mineração de Dados**. Editora Ciência Moderna Ltda., 2009.
#
# WITTEN, I. H.; FRANK, E. **Data Mining: Practical Machine Learning Tools and Techniques**. Morgan Kaufmann Publishers, 2005.
