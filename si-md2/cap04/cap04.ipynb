# %% [markdown]
# [![](images/colab-badge.png)](https://colab.research.google.com/github/fzampirolli/si-md2/blob/main/si-md2/notebooks_alunos/cap04/cap04_aluno.ipynb)

# %% [markdown]
# # Classificação e Regras de Classificação

# %% [markdown]
# ## Referências do Capítulo
#
#
# Tem que citar neste capítulo: @goldschmidt2005, @pinheiro2008, @tan2009
#
#
# \printbibliography[heading=none]
