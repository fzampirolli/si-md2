# %% [markdown]
# # Sistemas Inteligentes

# %% [markdown]
# Exemplo de tabela-imagem @tbl-1-1.
#
# ![Relação entre Dados, Informação e Conhecimento](images/fig1_1.png){#tbl-1-1}

# %% [markdown]
# Exemplo de figura @fig-1-1.
#
# ![Relação entre Dados, Informação e Conhecimento](images/fig1_1.png){#fig-1-1}

# %% [markdown]
# A equação @eq-1-1.
#
# $$
# x^3
# $$ {#eq-1-1}

# %% [markdown]
# A tabela @tbl-1-X.
#
# | x | y |
# |---|---|
# | 1 | 2 |
#
# : Legenda da tabela {#tbl-1-X}

# %% [markdown]
# Exemplo de ref direta: segundo @forouzan2011, em final de frase [@forouzan2011].

# %% [markdown]
# ## Referências do Capítulo
#
# Tem que citar neste capítulo: @forouzan2011, @goldschmidt2005, @han2008, @padhy2010, @pinheiro2008, @rezende2005, @russell2004, @tan2009, @witten2005
#
# \printbibliography[heading=none]
